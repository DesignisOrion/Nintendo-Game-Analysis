# %% [markdown]
# # Retro Game Data (Nintendo)
# In this project, I wanted to dive deep into the dataset of Nintendo video games and consoles. The goal of the project is to execute data analysis of the data using pandas. One data is analyzed, visualization will be executed using matplotlib. Enjoy!
#
# Dataset Link :https://www.kaggle.com/mrmorj/nintendo-games-dataset

# %%
#!pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
ningames = pd.read_csv("data.csv")
ningames
# Out:
#       meta_score                                            title platform  \
# 0            NaN             Super Mario 3D World + Bowser's Fury   Switch
# 1            NaN            Super Smash Bros. Ultimate: Sephiroth   Switch
# 2           66.0              Fitness Boxing 2: Rhythm & Exercise   Switch
# 3           63.0  Fire Emblem: Shadow Dragon & the Blade of Light   Switch
# 4           79.0                 Hyrule Warriors: Age of Calamity   Switch
# ...          ...                                              ...      ...
# 1021         NaN                                      Bayonetta 3   Switch
# 1022         NaN   The Legend of Zelda: Breath of the Wild Sequel   Switch
# 1023         NaN                                   Yo-kai Watch 4   Switch
# 1024         NaN                                    Pokemon Sleep      iOS
# 1025         NaN                                 New Pokemon Snap   Switch
#
#               date  user_score  \
# 0     Feb 12, 2021         NaN
# ...

# %%
list(ningames.columns)
# Out:
# ['meta_score',
#  'title',
#  'platform',
#  'date',
#  'user_score',
#  'link',
#  'esrb_rating',
#  'developers',
#  'genres']

# %%
new_data = ningames.drop(['meta_score', 'platform', 'date', 'user_score', 'esrb_rating', 'developers', 'link'], axis = 1)

# %%
new_data.to_csv('ningames.csv', header=True, index=False)

# %%
nindata = pd.read_csv("ningames.csv")
nindata.head(20)
# Out:
#                                                 title  \
# 0                Super Mario 3D World + Bowser's Fury
# 1               Super Smash Bros. Ultimate: Sephiroth
# 2                 Fitness Boxing 2: Rhythm & Exercise
# 3     Fire Emblem: Shadow Dragon & the Blade of Light
# 4                    Hyrule Warriors: Age of Calamity
# 5        Pokemon Sword + Pokemon Sword Expansion Pass
# 6      Pokemon Shield + Pokemon Shield Expansion Pass
# 7                                     Pikmin 3 Deluxe
# 8                                       Part Time UFO
# 9   Cadence of Hyrule: Crypt of the NecroDancer Fe...
# 10           Pokemon Sword / Shield: The Crown Tundra
# 11                      Mario Kart Live: Home Circuit
# 12           Super Smash Bros. Ultimate: Steve & Alex
# 13            Mario Kart 8 Deluxe + Super Mario Party
# 14                               Super Mario Bros. 35
# 15  Cadence of Hyrule: Crypt of the NecroDancer Fe...
# ...

# %%
list(nindata.genres)
# Out:
# ["['Action', 'Platformer', '3D']",
#  "['Action', '2D', 'Fighting']",
#  "['Miscellaneous', 'Exercise / Fitness']",
#  "['Strategy', 'Turn-Based', 'Tactics']",
#  '[\'Action\', "Beat-\'Em-Up", \'3D\']',
#  "['Role-Playing', 'Trainer']",
#  "['Role-Playing', 'Trainer']",
#  "['Strategy', 'Real-Time', 'General']",
#  "['Action', 'Arcade']",
#  "['Action', 'Rhythm', 'Music']",
#  "['Role-Playing', 'Trainer']",
#  "['Racing', 'Arcade', 'Automobile']",
#  "['Action', 'Fighting', '2D']",
#  "['Miscellaneous', 'Compilation']",
#  "['Action', 'Platformer', '2D']",
#  "['Action', 'Rhythm', 'Music']",
#  "['Action', 'Fighting', '2D']",
#  "['Miscellaneous', 'Compilation']",
#  "['Action', 'Rhythm', 'Music']",
#  "['Action', 'Rhythm', 'Music']",
#  "['Role-Playing', 'General']",
#  "['Action', 'Fighting', '2D']",
#  "['Puzzle', 'Matching']",
#  "['Role-Playing', 'Trainer']",
#  "['Action', 'General']",
#  "['Miscellaneous', 'Party / Minigame']",
#  "['Role-Playing', 'Action RPG']",
# ...
